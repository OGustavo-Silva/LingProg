# %% [markdown]
# 1 Faça um Programa que peça o raio de um círculo, calcule e mostre sua área.

# %%
import math

raio = int(input("Digite o raio o circulo: "))
area = (math.pi)*(raio**2)
area
# Out:
# Digite o raio o circulo: 5
# 78.53981633974483

# %% [markdown]
# 2 Faça um Programa que calcule a área de um quadrado, em seguida mostre o dobro
# desta área para o usuário.

# %%
peri = int(input("Informe um número para ser um lado do quadrado: "))
area = peri*peri
dobro = area*2
print("O dobro da área do valor informado é ",dobro)
# Out:
# Informe um número para ser um lado do quadrado: 8
# O dobro da área do valor informado é  128

# %% [markdown]
# 3 Faça um Programa que pergunte quanto você ganha por hora e o número de horas
# trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
ganho = float(input("Digite o quanto você ganha por hora: "))
horas = int(input("informe as horas trabalhadas no mês: "))
salario = ganho*horas
print("Seu salário deverá ser de: R$",salario)
# Out:
# Digite o quanto você ganha por hora: 5.5
# informe as horas trabalhadas no mês: 100
# Seu salário deverá ser de: R$ 550.0

# %% [markdown]
# 4 Faça um Programa que peça a temperatura em graus Farenheit, transforme e
# mostre a temperatura em graus Celsius. C = (5 * (F-32) / 9).

# %%
faren = float(input("Informe a temperatura em Farenheit"))
celsius = (5*(faren-32)/9)
print("A temperatura em Celsius é: ",celsius)
# Out:
# Informe a temperatura em Farenheit 98
# A temperatura em Celsius é:  36.666666666666664

# %% [markdown]
# 5 Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre
# em graus Farenheit.

# %%
celsius = float(input("Informe a temperatu em Celsius: "))
faren = (celsius * 9/5) + 32
print("A temperatura em Farenheit é: ",faren)
# Out:
# Informe a temperatu em Celsius:  5
# A temperatura em Farenheit é:  41.0

# %% [markdown]
# 6 Faça um Programa que peça 2 números inteiros e um número real. Calcule e
# mostre:
# - o produto do dobro do primeiro com metade do segundo .
# - a soma do triplo do primeiro com o terceiro.
# - o terceiro elevado ao cubo.

# %%
int1 = int(input("informe um numero inteiro"))
int2 = int(input("informe outro inteiro"))
real = float(input("informe um numero real"))
prod = (int1*2)*(int2/2)
soma = (int1*3)+real
cubo = real**3
print("O produto do dobro do primeiro com metade do segundo: ",prod)
print("A soma do triplo do primeiro com o terceiro: ",soma)
print("O terceiro elevado ao cubo: ",cubo)
# Out:
# informe um numero inteiro 10
# informe outro inteiro 5
# informe um numero real 2.5
# O produto do dobro do primeiro com metade do segundo:  50.0
# A soma do triplo do primeiro com o terceiro:  32.5
# O terceiro elevado ao cubo:  15.625

# %% [markdown]
# 7 João Papo-de-Pescador, homem de bem, comprou um microcomputador para
# controlar o rendimento diário de seu trabalho. Toda vez que ele traz um peso de
# peixes maior que o estabelecido pelo regulamento de pesca do estado de São Paulo
# (50 quilos) deve pagar uma multa de R$ 4,00 por quilo excedente. João precisa que
# você faça um programa que leia a variável peso (peso de peixes) e verifique se há
# excesso. Se houver, gravar na variável excesso e na variável multa o valor da multa
# que João deverá pagar. Caso contrário mostrar tais variáveis com o conteúdo ZERO.

# %%
peso = float(input("Informe o peso dos peixes: "))
exce = peso-50
if(exce > 0):
    multa = exce * 4.0
    print("O peso excedeu em ",exce,"KG, e você deverá pagar uma multa de: R$",multa)
else:
    print("Peso dentro do limite! liberado")
# Out:
# Informe o peso dos peixes:  51
# O peso excedeu em  1.0 KG, e você deverá pagar uma multa de: R$ 4.0
